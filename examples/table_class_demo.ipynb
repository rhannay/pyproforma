# %% [markdown]
# # Table Class Demo
#
# This notebook demonstrates the core functionality of the `pyproforma.Table` class, including:
# - Creating tables
# - Indexing and accessing cells
# - Styling rows and columns
# - Setting values
# - Working with cell properties

# %%
from pyproforma.table import Table, Cell

# %% [markdown]
# ## 1. Creating Tables
#
# Tables can be created from Cell objects or raw values.

# %%
# Create a table from Cell objects
table = Table(cells=[
    [Cell("Product"), Cell("Q1"), Cell("Q2"), Cell("Q3"), Cell("Q4")],
    [Cell("Widget A"), Cell(1000), Cell(1200), Cell(1100), Cell(1300)],
    [Cell("Widget B"), Cell(800), Cell(850), Cell(900), Cell(950)],
    [Cell("Widget C"), Cell(1500), Cell(1600), Cell(1550), Cell(1700)],
])
table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: right;">Product</th><th style="text-align: right;">Q1</th><th style="text-align: right;">Q2</th><th style="text-align: right;">Q3</th><th style="text-align: right;">Q4</th></tr></thead><tbody><tr><td style="text-align: right">Widget A</td><td style="text-align: right">1000</td><td style="text-align: right">1200</td><td style="text-align: right">1100</td><td style="text-align: right">1300</td></tr><tr><td style="text-align: right">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">950</td></tr><tr><td style="text-align: right">Widget C</td><td style="text-align: right">1500</td><td style="text-align: right">1600</td><td style="text-align: right">1550</td><td style="text-align: right">1700</td></tr></tbody></table></div>

# %%
# Create a table from raw values (automatically converted to Cells)
simple_table = Table(cells=[
    ["Name", "Age", "City"],
    ["Alice", 30, "NYC"],
    ["Bob", 25, "LA"],
    ["Charlie", 35, "Chicago"],
])
simple_table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: right;">Name</th><th style="text-align: right;">Age</th><th style="text-align: right;">City</th></tr></thead><tbody><tr><td style="text-align: right">Alice</td><td style="text-align: right">30</td><td style="text-align: right">NYC</td></tr><tr><td style="text-align: right">Bob</td><td style="text-align: right">25</td><td style="text-align: right">LA</td></tr><tr><td style="text-align: right">Charlie</td><td style="text-align: right">35</td><td style="text-align: right">Chicago</td></tr></tbody></table></div>

# %% [markdown]
# ## 2. Table Properties
#
# Access table dimensions with `.row_count` and `.col_count`.

# %%
print(f"Rows: {table.row_count}")
print(f"Columns: {table.col_count}")
# Out:
# Rows: 4
# Columns: 5

# %% [markdown]
# ## 3. Indexing and Cell Access
#
# Access individual cells using `table[row, col]` syntax (zero-based indexing).

# %%
# Get a cell value
cell = table[1, 1]
print(f"Cell at [1, 1]: {cell.value}")

# Modify a cell's value
table[1, 1].value = 1250
print(f"Updated value: {table[1, 1].value}")

# Replace entire cell
table[1, 2] = Cell(1275, bold=True)
table
# Out:
# Cell at [1, 1]: 1000
# Updated value: 1250
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: right;">Product</th><th style="text-align: right;">Q1</th><th style="text-align: right;">Q2</th><th style="text-align: right;">Q3</th><th style="text-align: right;">Q4</th></tr></thead><tbody><tr><td style="text-align: right">Widget A</td><td style="text-align: right">1250</td><td style="text-align: right; font-weight: bold">1275</td><td style="text-align: right">1100</td><td style="text-align: right">1300</td></tr><tr><td style="text-align: right">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">950</td></tr><tr><td style="text-align: right">Widget C</td><td style="text-align: right">1500</td><td style="text-align: right">1600</td><td style="text-align: right">1550</td><td style="text-align: right">1700</td></tr></tbody></table></div>

# %% [markdown]
# ## 4. Styling Rows
#
# Use `style_row()` to apply formatting to all cells in a row.

# %%
# Style the header row
table.style_row(0, bold=True, background_color='lightgray', align='center')
table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: center; font-weight: bold background-color: lightgray">Product</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q1</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q2</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q3</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q4</th></tr></thead><tbody><tr><td style="text-align: right">Widget A</td><td style="text-align: right">1250</td><td style="text-align: right; font-weight: bold">1275</td><td style="text-align: right">1100</td><td style="text-align: right">1300</td></tr><tr><td style="text-align: right">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">950</td></tr><tr><td style="text-align: right">Widget C</td><td style="text-align: right">1500</td><td style="text-align: right">1600</td><td style="text-align: right">1550</td><td style="text-align: right">1700</td></tr></tbody></table></div>

# %%
# Add a total row with special formatting
table.cells.append([
    Cell("Total"),
    Cell(3300),
    Cell(3650),
    Cell(3550),
    Cell(3950),
])

# Style the total row
table.style_row(4, bold=True, top_border='single', bottom_border='double')
table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: center; font-weight: bold background-color: lightgray">Product</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q1</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q2</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q3</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q4</th></tr></thead><tbody><tr><td style="text-align: right">Widget A</td><td style="text-align: right">1250</td><td style="text-align: right; font-weight: bold">1275</td><td style="text-align: right">1100</td><td style="text-align: right">1300</td></tr><tr><td style="text-align: right">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">950</td></tr><tr><td style="text-align: right">Widget C</td><td style="text-align: right">1500</td><td style="text-align: right">1600</td><td style="text-align: right">1550</td><td style="text-align: right">1700</td></tr><tr><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">Total</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3300</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3650</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3550</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3950</td></tr></tbody></table></div>

# %% [markdown]
# ## 5. Styling Columns
#
# Use `style_col()` to apply formatting to all cells in a column.

# %%
# Style the product name column (data rows only)
for row_idx in range(1, len(table.cells)):
    table[row_idx, 0].bold = True
    table[row_idx, 0].align = 'left'

# Format numeric columns with thousand separators (data rows only)
for row_idx in range(1, len(table.cells)):
    for col_idx in range(1, 5):
        table[row_idx, col_idx].value_format = 'no_decimals'
        table[row_idx, col_idx].align = 'right'

table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: center; font-weight: bold background-color: lightgray">Product</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q1</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q2</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q3</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q4</th></tr></thead><tbody><tr><td style="text-align: left; font-weight: bold">Widget A</td><td style="text-align: right">1,250</td><td style="text-align: right; font-weight: bold">1,275</td><td style="text-align: right">1,100</td><td style="text-align: right">1,300</td></tr><tr><td style="text-align: left; font-weight: bold">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">950</td></tr><tr><td style="text-align: left; font-weight: bold">Widget C</td><td style="text-align: right">1,500</td><td style="text-align: right">1,600</td><td style="text-align: right">1,550</td><td style="text-align: right">1,700</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">Total</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,300</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,650</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,550</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,950</td></tr></tbody></table></div>

# %% [markdown]
# ## 6. Setting Row Values
#
# Use `set_row_values()` to update multiple cells at once while preserving formatting.

# %%
# Update Widget A sales (skip the product name column)
# Note: Widget A is at row index 1
table.set_row_values(1, [1100, 1300, 1150, 1400], start_col=1)
table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: center; font-weight: bold background-color: lightgray">Product</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q1</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q2</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q3</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q4</th></tr></thead><tbody><tr><td style="text-align: left; font-weight: bold">Widget A</td><td style="text-align: right">1,100</td><td style="text-align: right; font-weight: bold">1,300</td><td style="text-align: right">1,150</td><td style="text-align: right">1,400</td></tr><tr><td style="text-align: left; font-weight: bold">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">950</td></tr><tr><td style="text-align: left; font-weight: bold">Widget C</td><td style="text-align: right">1,500</td><td style="text-align: right">1,600</td><td style="text-align: right">1,550</td><td style="text-align: right">1,700</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">Total</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,300</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,650</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,550</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,950</td></tr></tbody></table></div>

# %%
# Recalculate totals (sum Widget A, B, C - rows 1, 2, 3)
totals = []
for col_idx in range(1, 5):
    total = sum(table[row, col_idx].value for row in range(1, 4))
    totals.append(total)

# Update total row (row 4)
table.set_row_values(4, totals, start_col=1)
table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: center; font-weight: bold background-color: lightgray">Product</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q1</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q2</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q3</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q4</th></tr></thead><tbody><tr><td style="text-align: left; font-weight: bold">Widget A</td><td style="text-align: right">1,100</td><td style="text-align: right; font-weight: bold">1,300</td><td style="text-align: right">1,150</td><td style="text-align: right">1,400</td></tr><tr><td style="text-align: left; font-weight: bold">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">950</td></tr><tr><td style="text-align: left; font-weight: bold">Widget C</td><td style="text-align: right">1,500</td><td style="text-align: right">1,600</td><td style="text-align: right">1,550</td><td style="text-align: right">1,700</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">Total</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,400</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,750</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,600</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">4,050</td></tr></tbody></table></div>

# %% [markdown]
# ## 7. Setting Column Values
#
# Use `set_col_values()` to update a column while preserving formatting.

# %%
# Update Q4 values for Widget A, B, C individually (can't use set_col_values because of the total row)
table[1, 4].value = 1500  # Widget A
table[2, 4].value = 1000  # Widget B  
table[3, 4].value = 1800  # Widget C

# Recalculate Q4 total
q4_total = sum(table[row, 4].value for row in range(1, 4))
table[4, 4].value = q4_total

table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: center; font-weight: bold background-color: lightgray">Product</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q1</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q2</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q3</th><th style="text-align: center; font-weight: bold background-color: lightgray">Q4</th></tr></thead><tbody><tr><td style="text-align: left; font-weight: bold">Widget A</td><td style="text-align: right">1,100</td><td style="text-align: right; font-weight: bold">1,300</td><td style="text-align: right">1,150</td><td style="text-align: right">1,500</td></tr><tr><td style="text-align: left; font-weight: bold">Widget B</td><td style="text-align: right">800</td><td style="text-align: right">850</td><td style="text-align: right">900</td><td style="text-align: right">1,000</td></tr><tr><td style="text-align: left; font-weight: bold">Widget C</td><td style="text-align: right">1,500</td><td style="text-align: right">1,600</td><td style="text-align: right">1,550</td><td style="text-align: right">1,800</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">Total</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,400</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,750</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">3,600</td><td style="text-align: right; font-weight: bold; border-top: 1px solid black; border-bottom: 3px double black">4,300</td></tr></tbody></table></div>

# %% [markdown]
# ## 8. Cell Formatting Options
#
# Cells support various formatting options.

# %%
# Create a table showcasing different formats
format_demo = Table(cells=[
    [Cell("Format Type"), Cell("Raw Value"), Cell("Formatted")],
    [Cell("No Decimals"), Cell(1234.567), Cell(1234.567, value_format='no_decimals')],
    [Cell("Two Decimals"), Cell(1234.567), Cell(1234.567, value_format='two_decimals')],
    [Cell("Percent"), Cell(0.1234), Cell(0.1234, value_format='percent')],
    [Cell("Percent (1 decimal)"), Cell(0.1234), Cell(0.1234, value_format='percent_one_decimal')],
    [Cell("Percent (2 decimals)"), Cell(0.1234), Cell(0.1234, value_format='percent_two_decimals')],
    [Cell("String"), Cell(12345), Cell(12345, value_format='str')],
])

# Style the header
format_demo.style_row(0, bold=True, background_color='lightblue')
format_demo.style_col(0, bold=True)

format_demo
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: right; font-weight: bold background-color: lightblue">Format Type</th><th style="text-align: right; font-weight: bold background-color: lightblue">Raw Value</th><th style="text-align: right; font-weight: bold background-color: lightblue">Formatted</th></tr></thead><tbody><tr><td style="text-align: right; font-weight: bold">No Decimals</td><td style="text-align: right">1234.567</td><td style="text-align: right">1,235</td></tr><tr><td style="text-align: right; font-weight: bold">Two Decimals</td><td style="text-align: right">1234.567</td><td style="text-align: right">1,234.57</td></tr><tr><td style="text-align: right; font-weight: bold">Percent</td><td style="text-align: right">0.1234</td><td style="text-align: right">12%</td></tr><tr><td style="text-align: right; font-weight: bold">Percent (1 decimal)</td><td style="text-align: right">0.1234</td><td style="text-align: right">12.3%</td></tr><tr><td style="text-align: right; font-weight: bold">Percent (2 decimals)</td><td style="text-align: right">0.1234</td><td style="text-align: right">12.34%</td></tr><tr><td style="text-align: right; font-weight: bold">String</td><td style="text-align: right">12345</td><td style="text-align: right">12345</td></tr></tbody></table></div>

# %% [markdown]
# ## 9. Color and Border Options

# %%
# Create a table with colors and borders
styled_table = Table(cells=[
    [Cell("Category"), Cell("Value"), Cell("Status")],
    [Cell("Revenue"), Cell(50000), Cell("Good")],
    [Cell("Expenses"), Cell(30000), Cell("Normal")],
    [Cell("Profit"), Cell(20000), Cell("Excellent")],
])

# Header styling
styled_table.style_row(0, bold=True, background_color='darkblue', font_color='white', align='center')

# Highlight profit row
styled_table.style_row(3, background_color='lightgreen', bold=True)

# Add borders
styled_table.style_row(0, bottom_border='double')
styled_table.style_row(3, top_border='single', bottom_border='double')

# Format values (only data rows, not header)
for row_idx in range(1, 4):
    styled_table[row_idx, 1].value_format = 'no_decimals'
    styled_table[row_idx, 1].align = 'right'

styled_table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table th {
#             background-color: #f0f0f0;
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             font-weight: 600;
#             text-align: center;
#             color: #333;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><thead><tr><th style="text-align: center; font-weight: bold background-color: darkblue color: white">Category</th><th style="text-align: center; font-weight: bold background-color: darkblue color: white">Value</th><th style="text-align: center; font-weight: bold background-color: darkblue color: white">Status</th></tr></thead><tbody><tr><td style="text-align: right">Revenue</td><td style="text-align: right">50,000</td><td style="text-align: right">Good</td></tr><tr><td style="text-align: right">Expenses</td><td style="text-align: right">30,000</td><td style="text-align: right">Normal</td></tr><tr><td style="text-align: right; font-weight: bold; background-color: lightgreen; border-top: 1px solid black; border-bottom: 3px double black">Profit</td><td style="text-align: right; font-weight: bold; background-color: lightgreen; border-top: 1px solid black; border-bottom: 3px double black">20,000</td><td style="text-align: right; font-weight: bold; background-color: lightgreen; border-top: 1px solid black; border-bottom: 3px double black">Excellent</td></tr></tbody></table></div>

# %% [markdown]
# ## 10. Export to Excel

# %%
# Export the styled table to Excel (preserves formatting)
table.to_excel('sales_report.xlsx')
print("Table exported to sales_report.xlsx")
# Out:
# Table exported to sales_report.xlsx
# Table exported to sales_report.xlsx

# %% [markdown]
# ## 11. Convert to DataFrame

# %%
# Convert to pandas DataFrame (raw values only)
df = table.to_dataframe()
print(df)
# Out:
#     Product    Q1    Q2    Q3    Q4
# 0  Widget A  1100  1300  1150  1500
# 1  Widget B   800   850   900  1000
# 2  Widget C  1500  1600  1550  1800
# 3     Total  3400  3750  3600  4300

# %%
# Convert to styled DataFrame (preserves formatting)
styled_df = table.to_styled_df()
styled_df
# Out:
# <style type="text/css">
# #T_efac4 th.col_heading.level0.col0 {
#   text-align: center;
# }
# #T_efac4 th.col_heading.level0.col1 {
#   text-align: center;
# }
# #T_efac4 th.col_heading.level0.col2 {
#   text-align: center;
# }
# #T_efac4 th.col_heading.level0.col3 {
#   text-align: center;
# }
# #T_efac4 th.col_heading.level0.col4 {
#   text-align: center;
# }
# #T_efac4_row0_col0, #T_efac4_row1_col0, #T_efac4_row2_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# #T_efac4_row0_col1, #T_efac4_row0_col3, #T_efac4_row0_col4, #T_efac4_row1_col1, #T_efac4_row1_col2, #T_efac4_row1_col3, #T_efac4_row1_col4, #T_efac4_row2_col1, #T_efac4_row2_col2, #T_efac4_row2_col3, #T_efac4_row2_col4 {
#   text-align: right;
# }
# #T_efac4_row0_col2 {
#   font-weight: bold;
#   text-align: right;
# }
# #T_efac4_row3_col0 {
#   font-weight: bold;
#   text-align: left;
#   border-bottom: 3px double black;
#   border-top: 1px solid black;
# }
# #T_efac4_row3_col1, #T_efac4_row3_col2, #T_efac4_row3_col3, #T_efac4_row3_col4 {
#   font-weight: bold;
#   text-align: right;
#   border-bottom: 3px double black;
#   border-top: 1px solid black;
# }
# </style>
# <table id="T_efac4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efac4_level0_col0" class="col_heading level0 col0" >Product</th>
#       <th id="T_efac4_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_efac4_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_efac4_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_efac4_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efac4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efac4_row0_col0" class="data row0 col0" >Widget A</td>
#       <td id="T_efac4_row0_col1" class="data row0 col1" >1,100</td>
#       <td id="T_efac4_row0_col2" class="data row0 col2" >1,300</td>
#       <td id="T_efac4_row0_col3" class="data row0 col3" >1,150</td>
#       <td id="T_efac4_row0_col4" class="data row0 col4" >1,500</td>
#     </tr>
#     <tr>
#       <th id="T_efac4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efac4_row1_col0" class="data row1 col0" >Widget B</td>
#       <td id="T_efac4_row1_col1" class="data row1 col1" >800</td>
#       <td id="T_efac4_row1_col2" class="data row1 col2" >850</td>
#       <td id="T_efac4_row1_col3" class="data row1 col3" >900</td>
#       <td id="T_efac4_row1_col4" class="data row1 col4" >1,000</td>
#     </tr>
#     <tr>
#       <th id="T_efac4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efac4_row2_col0" class="data row2 col0" >Widget C</td>
#       <td id="T_efac4_row2_col1" class="data row2 col1" >1,500</td>
#       <td id="T_efac4_row2_col2" class="data row2 col2" >1,600</td>
#       <td id="T_efac4_row2_col3" class="data row2 col3" >1,550</td>
#       <td id="T_efac4_row2_col4" class="data row2 col4" >1,800</td>
#     </tr>
#     <tr>
#       <th id="T_efac4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efac4_row3_col0" class="data row3 col0" >Total</td>
#       <td id="T_efac4_row3_col1" class="data row3 col1" >3,400</td>
#       <td id="T_efac4_row3_col2" class="data row3 col2" >3,750</td>
#       <td id="T_efac4_row3_col3" class="data row3 col3" >3,600</td>
#       <td id="T_efac4_row3_col4" class="data row3 col4" >4,300</td>
#     </tr>
#   </tbody>
# </table>
