# %%
from simple_model_2 import simple_model_2 as model

# %%
model.line_item_names
table = model['technology'].table()
table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# ...

# %%
model.line_item('technology')
# Out:
# LineItemResults(name='technology', source_type='line_item')
