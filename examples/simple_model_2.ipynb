# %%
from simple_model_2 import simple_model_2 as model

# %%
table = model.tables.line_items()
table
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #d0d0d0;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #d0d0d0;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">name</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td><td style="text-align: center; font-weight: bold">2028</td></tr><tr><td style="text-align: left">product_sales</td><td style="text-align: right">800,000</td><td style="text-align: right">920,000</td><td style="text-align: right">1,058,000</td><td style="text-align: right">1,216,700</td><td style="text-align: right">1,399,205</td></tr><tr><td style="text-align: left">service_revenue</td><td style="text-align: right">300,000</td><td style="text-align: right">345,000</td><td style="text-align: right">396,750</td><td style="text-align: right">456,262</td><td style="text-align: right">524,702</td></tr><tr><td style="text-align: left">licensing_fees</td><td style="text-align: right">150,000</td><td style="text-align: right">172,500</td><td style="text-align: right">198,375</td><td style="text-align: right">228,131</td><td style="text-align: right">262,351</td></tr><tr><td style="text-align: left">total_revenues</td><td style="text-align: right">1,250,000</td><td style="text-align: right">1,437,500</td><td style="text-align: right">1,653,125</td><td style="text-align: right">1,901,093</td><td style="text-align: right">2,186,258</td></tr><tr><td style="text-align: left">salaries</td><td style="text-align: right">450,000</td><td style="text-align: right">495,000</td><td style="text-align: right">544,500</td><td style="text-align: right">598,950</td><td style="text-align: right">658,845</td></tr><tr><td style="text-align: left">marketing</td><td style="text-align: right">125,000</td><td style="text-align: right">137,500</td><td style="text-align: right">151,250</td><td style="text-align: right">166,375</td><td style="text-align: right">183,012</td></tr><tr><td style="text-align: left">rent_utilities</td><td style="text-align: right">80,000</td><td style="text-align: right">84,000</td><td style="text-align: right">88,200</td><td style="text-align: right">92,610</td><td style="text-align: right">97,240</td></tr><tr><td style="text-align: left">technology</td><td style="text-align: right">60,000</td><td style="text-align: right">66,000</td><td style="text-align: right">72,600</td><td style="text-align: right">79,860</td><td style="text-align: right">87,846</td></tr><tr><td style="text-align: left">total_expenses</td><td style="text-align: right">715,000</td><td style="text-align: right">782,500</td><td style="text-align: right">856,550</td><td style="text-align: right">937,795</td><td style="text-align: right">1,026,943</td></tr><tr><td style="text-align: left">ebitda</td><td style="text-align: right">535,000</td><td style="text-align: right">655,000</td><td style="text-align: right">796,575</td><td style="text-align: right">963,298</td><td style="text-align: right">1,159,315</td></tr></tbody></table></div>

# %%
model.line_item('technology')
# Out:
# LineItemResults(name='technology', source_type='line_item')
