# %% [markdown]
# # PyProforma v2 Tables Example

# %%
from pyproforma.v2 import FixedLine, FormulaLine, ProformaModel

# %% [markdown]
# ## Define Model

# %%
class FinancialModel(ProformaModel):
    """A simple financial model demonstrating table creation."""

    revenue = FixedLine(
        values={2024: 100000, 2025: 115000, 2026: 132000, 2027: 152000},
        label="Revenue",
    )

    operating_expenses = FormulaLine(
        formula=lambda a, li, t: li.revenue[t] * 0.55,
        label="Operating Expenses",
    )

    ebitda = FormulaLine(
        formula=lambda a, li, t: li.revenue[t] - li.operating_expenses[t],
        label="EBITDA",
    )

    tax_expense = FormulaLine(
        formula=lambda a, li, t: li.ebitda[t] * 0.21,
        label="Tax Expense",
    )

    net_income = FormulaLine(
        formula=lambda a, li, t: li.ebitda[t] - li.tax_expense[t],
        label="Net Income",
    )

# %%
# Create the model
model = FinancialModel(periods=[2024, 2025, 2026, 2027])

# %% [markdown]
# ## Table with all line items (showing names)

# %%
table = model.tables.line_items()
table.show()
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #e8e8e8;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #e8e8e8;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Name</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td></tr><tr><td style="text-align: left">revenue</td><td style="text-align: right">100,000</td><td style="text-align: right">115,000</td><td style="text-align: right">132,000</td><td style="text-align: right">152,000</td></tr><tr><td style="text-align: left">operating_expenses</td><td style="text-align: right">55,000</td><td style="text-align: right">63,250</td><td style="text-align: right">72,600</td><td style="text-align: right">83,600</td></tr><tr><td style="text-align: left">ebitda</td><td style="text-align: right">45,000</td><td style="text-align: right">51,750</td><td style="text-align: right">59,400</td><td style="text-align: right">68,400</td></tr><tr><td style="text-align: left">tax_expense</td><td style="text-align: right">9,450</td><td style="text-align: right">10,867</td><td style="text-align: right">12,474</td><td style="text-align: right">14,364</td></tr><tr><td style="text-align: left">net_income</td><td style="text-align: right">35,550</td><td style="text-align: right">40,882</td><td style="text-align: right">46,926</td><td style="text-align: right">54,036</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 2px solid black">Total</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">245,000</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">281,750</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">323,400</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">372,400</td></tr></tbody></table></div>

# %% [markdown]
# ## Table with specific line items (showing labels)

# %%
table = model.tables.line_items(
    line_items=["revenue", "ebitda", "net_income"],
    include_name=False,
    include_label=True,
)
table.show()
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #e8e8e8;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #e8e8e8;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Label</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td></tr><tr><td style="text-align: left">Revenue</td><td style="text-align: right">100,000</td><td style="text-align: right">115,000</td><td style="text-align: right">132,000</td><td style="text-align: right">152,000</td></tr><tr><td style="text-align: left">EBITDA</td><td style="text-align: right">45,000</td><td style="text-align: right">51,750</td><td style="text-align: right">59,400</td><td style="text-align: right">68,400</td></tr><tr><td style="text-align: left">Net Income</td><td style="text-align: right">35,550</td><td style="text-align: right">40,882</td><td style="text-align: right">46,926</td><td style="text-align: right">54,036</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 2px solid black">Total</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">180,550</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">207,632</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">238,326</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">274,436</td></tr></tbody></table></div>

# %% [markdown]
# ## Single line item using .table() method

# %%
revenue_result = model["revenue"]
revenue_table = revenue_result.table()
revenue_table.show()
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #e8e8e8;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #e8e8e8;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Label</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td></tr><tr><td style="text-align: left">Revenue</td><td style="text-align: right">100,000</td><td style="text-align: right">115,000</td><td style="text-align: right">132,000</td><td style="text-align: right">152,000</td></tr></tbody></table></div>

# %% [markdown]
# ## Single line item with name included

# %%
net_income_result = model["net_income"]
net_income_table = net_income_result.table(include_name=True)
net_income_table.show()
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #e8e8e8;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #e8e8e8;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Name</td><td style="text-align: left; font-weight: bold">Label</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td></tr><tr><td style="text-align: left">net_income</td><td style="text-align: left">Net Income</td><td style="text-align: right">35,550</td><td style="text-align: right">40,882</td><td style="text-align: right">46,926</td><td style="text-align: right">54,036</td></tr></tbody></table></div>

# %% [markdown]
# ## Line item with percent change analysis

# %%
revenue_pct_change = model["revenue"].table(include_percent_change=True)
revenue_pct_change.to_html()
# Out:
# '<style>\n        .pyproforma-table-container {\n            font-family: \'Segoe UI\', Tahoma, Geneva, Verdana, sans-serif;\n            font-size: 11pt;\n            margin: 10px 0;\n        }\n        .pyproforma-table {\n            border-collapse: collapse;\n            border: 1px solid #e8e8e8;\n            background-color: white;\n        }\n        .pyproforma-table td {\n            border: 1px solid #e8e8e8;\n            padding: 6px 12px;\n            color: #333;\n            background-color: white;\n        }\n        .pyproforma-table tbody tr:hover td {\n            background-color: #f9f9f9;\n        }\n    </style>\n<div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Label</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td></tr><tr><td style="text-align: left">Revenue</td><td style="text-align: right">100,000</td><td style="text-align: right">115,000</td><td style="text-align: right">132,000</td><td style="text-align: right">152,000</td></tr><tr><td style="text-align: left">Revenue % Change</td><td style="text-align: right"></td><td style="text-align: right">15.00%</td><td style="text-align: right">14.78%</td><td style="text-align: right">15.15%</td></tr></tbody></table></div>'

# %% [markdown]
# ## Line item with cumulative change analysis

# %%
ebitda_cumulative = model["ebitda"].table(
    include_cumulative_change=True,
    include_cumulative_percent_change=True
)
ebitda_cumulative.to_html()
# Out:
# '<style>\n        .pyproforma-table-container {\n            font-family: \'Segoe UI\', Tahoma, Geneva, Verdana, sans-serif;\n            font-size: 11pt;\n            margin: 10px 0;\n        }\n        .pyproforma-table {\n            border-collapse: collapse;\n            border: 1px solid #e8e8e8;\n            background-color: white;\n        }\n        .pyproforma-table td {\n            border: 1px solid #e8e8e8;\n            padding: 6px 12px;\n            color: #333;\n            background-color: white;\n        }\n        .pyproforma-table tbody tr:hover td {\n            background-color: #f9f9f9;\n        }\n    </style>\n<div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Label</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td></tr><tr><td style="text-align: left">EBITDA</td><td style="text-align: right">45,000</td><td style="text-align: right">51,750</td><td style="text-align: right">59,400</td><td style="text-align: right">68,400</td></tr><tr><td style="text-align: left">EBITDA Cumulative Change</td><td style="text-align: right">0</td><td style="text-align: right">6,750</td><td style="text-align: right">14,400</td><td style="text-align: right">23,400</td></tr><tr><td style="text-align: left">EBITDA Cumulative % Change</td><td style="text-align: right">0%</td><td style="text-align: right">15%</td><td style="text-align: right">32%</td><td style="text-align: right">52%</td></tr></tbody></table></div>'

# %% [markdown]
# ## Line item with all analysis rows

# %%
net_income_analysis = model["net_income"].table(
    include_name=True,
    include_percent_change=True,
    include_cumulative_change=True,
    include_cumulative_percent_change=True
)
net_income_analysis.to_html()
# Out:
# '<style>\n        .pyproforma-table-container {\n            font-family: \'Segoe UI\', Tahoma, Geneva, Verdana, sans-serif;\n            font-size: 11pt;\n            margin: 10px 0;\n        }\n        .pyproforma-table {\n            border-collapse: collapse;\n            border: 1px solid #e8e8e8;\n            background-color: white;\n        }\n        .pyproforma-table td {\n            border: 1px solid #e8e8e8;\n            padding: 6px 12px;\n            color: #333;\n            background-color: white;\n        }\n        .pyproforma-table tbody tr:hover td {\n            background-color: #f9f9f9;\n        }\n    </style>\n<div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Name</td><td style="text-align: left; font-weight: bold">Label</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td><td style="text-align: center; font-weight: bold">2026</td><td style="text-align: center; font-weight: bold">2027</td></tr><tr><td style="text-align: left">net_income</td><td style="text-align: left">Net Income</td><td style="text-align: right">35,550</td><td style="text-align: right">40,882</td><td style="text-align: right">46,926</td><td style="text-align: right">54,036</td></tr><tr><td style="text-align: left">net_income</td><td style="text-align: left">Net Income % Change</td><td style="text-align: right"></td><td style="text-align: right">15.00%</td><td style="text-align: right">14.78%</td><td style="text-align: right">15.15%</td></tr><tr><td style="text-align: left">net_income</td><td style="text-align: left">Net Income Cumulative Change</td><td style="text-align: right">0</td><td style="text-align: right">5,332</td><td style="text-align: right">11,376</td><td style="text-align: right">18,486</td></tr><tr><td style="text-align: left">net_income</td><td style="text-align: left">Net Income Cumulative % Change</td><td style="text-align: right">0%</td><td style="text-align: right">15%</td><td style="text-align: right">32%</td><td style="text-align: right">52%</td></tr></tbody></table></div>'
