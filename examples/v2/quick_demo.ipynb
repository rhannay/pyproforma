# %% [markdown]
# # Quick Demo: Tags and Reserved Words

# %%
from pyproforma.v2 import FixedLine, FormulaLine, ProformaModel

# %% [markdown]
# ## Define the Model
#
# Line items are tagged with `"income"` or `"expense"`. Formulas use `li.tag["tagname"][t]` to sum all items with a given tag.

# %%
class SimpleModel(ProformaModel):
    sales = FixedLine(values={2024: 1000, 2025: 1100}, tags=["income", "recurring"], label="Sales")
    interest = FixedLine(values={2024: 50, 2025: 55}, tags=["income"], label="Interest Income")
    costs = FixedLine(values={2024: 600, 2025: 660}, tags=["expense", "recurring"], label="Costs")
    taxes = FixedLine(values={2024: 100, 2025: 110}, tags=["expense"], label="Taxes")
    total_income = FormulaLine(formula=lambda a, li, t: li.tag["income"][t], label="Total Income")
    total_expense = FormulaLine(formula=lambda a, li, t: li.tag["expense"][t], label="Total Expense")
    profit = FormulaLine(formula=lambda a, li, t: li.tag["income"][t] - li.tag["expense"][t], label="Profit")

model = SimpleModel(periods=[2024, 2025])

# %% [markdown]
# ## Tag-Based Summation
#
# Use `model.tag["tagname"].table()` to show the sum of all items with a given tag.

# %%
model.tag["income"].table().show()
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #e8e8e8;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #e8e8e8;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Name</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td></tr><tr><td style="text-align: left">sales</td><td style="text-align: right">1,000</td><td style="text-align: right">1,100</td></tr><tr><td style="text-align: left">interest</td><td style="text-align: right">50</td><td style="text-align: right">55</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 2px solid black">Total</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">1,050</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">1,155</td></tr></tbody></table></div>

# %%
model.tag["expense"].table().show()
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #e8e8e8;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #e8e8e8;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Name</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td></tr><tr><td style="text-align: left">costs</td><td style="text-align: right">600</td><td style="text-align: right">660</td></tr><tr><td style="text-align: left">taxes</td><td style="text-align: right">100</td><td style="text-align: right">110</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 2px solid black">Total</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">700</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">770</td></tr></tbody></table></div>

# %% [markdown]
# ## Full Model Table

# %%
model.tables.line_items(include_label=True).show()
# Out:
# <style>
#         .pyproforma-table-container {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             font-size: 11pt;
#             margin: 10px 0;
#         }
#         .pyproforma-table {
#             border-collapse: collapse;
#             border: 1px solid #e8e8e8;
#             background-color: white;
#         }
#         .pyproforma-table td {
#             border: 1px solid #e8e8e8;
#             padding: 6px 12px;
#             color: #333;
#             background-color: white;
#         }
#         .pyproforma-table tbody tr:hover td {
#             background-color: #f9f9f9;
#         }
#     </style>
# <div class="pyproforma-table-container"><table class="pyproforma-table"><tbody><tr><td style="text-align: left; font-weight: bold">Name</td><td style="text-align: left; font-weight: bold">Label</td><td style="text-align: center; font-weight: bold">2024</td><td style="text-align: center; font-weight: bold">2025</td></tr><tr><td style="text-align: left">sales</td><td style="text-align: left">Sales</td><td style="text-align: right">1,000</td><td style="text-align: right">1,100</td></tr><tr><td style="text-align: left">interest</td><td style="text-align: left">Interest Income</td><td style="text-align: right">50</td><td style="text-align: right">55</td></tr><tr><td style="text-align: left">costs</td><td style="text-align: left">Costs</td><td style="text-align: right">600</td><td style="text-align: right">660</td></tr><tr><td style="text-align: left">taxes</td><td style="text-align: left">Taxes</td><td style="text-align: right">100</td><td style="text-align: right">110</td></tr><tr><td style="text-align: left">total_income</td><td style="text-align: left">Total Income</td><td style="text-align: right">1,050</td><td style="text-align: right">1,155</td></tr><tr><td style="text-align: left">total_expense</td><td style="text-align: left">Total Expense</td><td style="text-align: right">700</td><td style="text-align: right">770</td></tr><tr><td style="text-align: left">profit</td><td style="text-align: left">Profit</td><td style="text-align: right">350</td><td style="text-align: right">385</td></tr><tr><td style="text-align: left; font-weight: bold; border-top: 2px solid black"></td><td style="text-align: left; font-weight: bold; border-top: 2px solid black">Total</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">3,850</td><td style="text-align: right; font-weight: bold; border-top: 2px solid black">4,235</td></tr></tbody></table></div>

# %% [markdown]
# ## Reserved Words Validation
#
# Reserved names (like `tags`, `li`, `t`, etc.) cannot be used as line item names.

# %%
try:
    class BadModel(ProformaModel):
        tags = FixedLine(values={2024: 100})
except ValueError as e:
    print(f"Expected error: {e}")
# Out:
# Expected error: 'tags' is a reserved word and cannot be used as a line item or assumption name. Reserved words include namespace accessors (li, av, tags, tables), formula parameters (t, a), model properties (periods), and Python keywords.
